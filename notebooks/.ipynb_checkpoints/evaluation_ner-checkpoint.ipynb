# %%
import json
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 from pathlib import Path
# ----> 4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
def load_results(filepath: str) -> dict:
    """Carga resultados desde un archivo JSON."""
    with open(filepath, 'r', encoding='utf-8') as f:
        return json.load(f)

def calculate_metrics(results: dict) -> dict:
    """Calcula métricas de NER."""
    tp, fp, fn = 0, 0, 0
    
    for sample in results['results']:
        expected = {(e['text'].lower(), e['type'].lower()) for e in sample['expected_entities']}
        predicted = {(e['text'].lower(), e['type'].lower()) for e in sample['predicted_entities']}
        
        tp += len(expected & predicted)
        fp += len(predicted - expected)
        fn += len(expected - predicted)
    
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_micro = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    
    return {
        'model': results['model'],
        'shot_type': results['shot_type'],
        'num_samples': results['num_samples'],
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro
    }

# %%
results_dir = Path('../results/ner')

result_files = {
    'GPT-4o-mini (few-shot)': results_dir / 'gpt-4o-mini/few_shot_5/gpt-4o-mini_ner_few_shot_5_test_20251212_135905.json',
    'GPT-4o-mini (zero-shot)': results_dir / 'gpt-4o-mini/zero_shot/gpt-4o-mini_ner_zero_shot_test_20251212_130743.json',
    'GPT-5.1 (few-shot)': results_dir / 'gpt-5.1-grande/few_shot_5/gpt-5.1-grande_ner_few_shot_5_test_20251222_125130.json',
    'GPT-5.1 (zero-shot)': results_dir / 'gpt-5.1-grande/zero_shot/gpt-5.1-grande_ner_zero_shot_test_20251222_124732.json',
    'Gemma-2-9B (few-shot)': results_dir / 'google_gemma-2-9b-it/few_shot_5/google_gemma-2-9b-it_ner_few_shot_5_test_20251215_125935.json',
    'Gemma-2-9B (zero-shot)': results_dir / 'google_gemma-2-9b-it/zero_shot/google_gemma-2-9b-it_ner_zero_shot_test_20251215_151733.json',
    'Llama-3.1-8B (few-shot)': results_dir / 'meta-llama_Meta-Llama-3.1-8B-Instruct/few_shot_5/meta-llama_Meta-Llama-3.1-8B-Instruct_ner_few_shot_5_test_20251215_174710.json',
    'Llama-3.1-8B (zero-shot)': results_dir / 'meta-llama_Meta-Llama-3.1-8B-Instruct/zero_shot/meta-llama_Meta-Llama-3.1-8B-Instruct_ner_zero_shot_test_20251215_193047.json',
    'Qwen-2.5-7B (few-shot)': results_dir / 'Qwen_Qwen2.5-7B-Instruct/few_shot_5/Qwen_Qwen2.5-7B-Instruct_ner_few_shot_5_test_20251215_104744.json',
    'Qwen-2.5-7B (zero-shot)': results_dir / 'Qwen_Qwen2.5-7B-Instruct/zero_shot/Qwen_Qwen2.5-7B-Instruct_ner_zero_shot_test_20251215_103242.json',
}

# %%
all_metrics = []

for name, filepath in result_files.items():
    
    results = load_results(filepath)
    metrics = calculate_metrics(results)
    metrics['name'] = name
    all_metrics.append(metrics)
    
    print(f"\n- {name}")
    print(f"  Samples: {metrics['num_samples']}")
    print(f"  Precision: {metrics['precision']:.4f}")
    print(f"  Recall: {metrics['recall']:.4f}")
    print(f"  F1 Micro: {metrics['f1_micro']:.4f}")
# Out:
# - GPT-4o-mini (few-shot)
#   Samples: 1129
#   Precision: 0.2913
#   Recall: 0.2998
#   F1 Micro: 0.2955
#
# - GPT-4o-mini (zero-shot)
#   Samples: 1129
#   Precision: 0.2455
#   Recall: 0.2263
#   F1 Micro: 0.2355
#
# - GPT-5.1 (few-shot)
#   Samples: 1129
#   Precision: 0.0000
#   Recall: 0.0000
#   F1 Micro: 0.0000
#
# - GPT-5.1 (zero-shot)
#   Samples: 1129
#   Precision: 0.0000
#   Recall: 0.0000
#   F1 Micro: 0.0000
#
# - Gemma-2-9B (few-shot)
#   Samples: 1129
#   Precision: 0.2483
#   Recall: 0.3284
#   F1 Micro: 0.2828
#
# - Gemma-2-9B (zero-shot)
#   Samples: 1129
#   Precision: 0.2298
#   Recall: 0.3229
#   F1 Micro: 0.2685
#
# - Llama-3.1-8B (few-shot)
#   Samples: 1129
#   Precision: 0.2255
#   Recall: 0.3378
#   F1 Micro: 0.2704
#
# - Llama-3.1-8B (zero-shot)
#   Samples: 1129
#   Precision: 0.1556
#   Recall: 0.1705
#   F1 Micro: 0.1627
#
# - Qwen-2.5-7B (few-shot)
#   Samples: 1129
#   Precision: 0.2884
#   Recall: 0.2835
#   F1 Micro: 0.2859
#
# - Qwen-2.5-7B (zero-shot)
#   Samples: 1129
#   Precision: 0.2549
#   Recall: 0.2011
#   F1 Micro: 0.2248

# %%
df_metrics = pd.DataFrame(all_metrics)
df_metrics = df_metrics[['name', 'num_samples', 'precision', 'recall', 'f1_micro']]
df_metrics = df_metrics.sort_values('f1_micro', ascending=False)

print("\n" + "="*80)
print("RESULTADOS COMPARATIVOS NER")
print("="*80)
print(df_metrics.to_string(index=False))
# Out:
# ================================================================================
# RESULTADOS COMPARATIVOS NER
# ================================================================================
#                     name  num_samples  precision   recall  f1_micro
#   GPT-4o-mini (few-shot)         1129   0.291273 0.299771  0.295461
#   Qwen-2.5-7B (few-shot)         1129   0.288417 0.283467  0.285920
#    Gemma-2-9B (few-shot)         1129   0.248324 0.328375  0.282793
#  Llama-3.1-8B (few-shot)         1129   0.225468 0.337815  0.270437
#   Gemma-2-9B (zero-shot)         1129   0.229752 0.322941  0.268490
#  GPT-4o-mini (zero-shot)         1129   0.245500 0.226259  0.235487
#  Qwen-2.5-7B (zero-shot)         1129   0.254895 0.201087  0.224816
# Llama-3.1-8B (zero-shot)         1129   0.155573 0.170481  0.162686
#       GPT-5.1 (few-shot)         1129   0.000000 0.000000  0.000000
#      GPT-5.1 (zero-shot)         1129   0.000000 0.000000  0.000000

# %% [markdown]
# # F1 con seqval

# %%
results
# Out:
# {'model': 'Qwen/Qwen2.5-7B-Instruct_ner',
#  'split': 'test',
#  'shot_type': 'zero_shot',
#  'timestamp': '20251215_103242',
#  'num_samples': 1129,
#  'entity_types': ['coreference',
#   'effect_size',
#   'intervention',
#   'outcome',
#   'population'],
#  'results': [{'sentence': 'Conclusiones Ambas intervenciones fueron localmente factibles .',
#    'expected_entities': [{'text': 'intervenciones', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'Ambas intervenciones',
#      'type': 'intervention'},
#     {'text': 'localmente factibles', 'type': 'outcome'}]},
#   {'sentence': 'Los hallazgos experimentales apuntan a tres conclusiones .',
#    'expected_entities': [{'text': 'hallazgos', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'grupos de tratamiento recibieron subvenciones no supervisadas de $ 382 por miembro .',
#    'expected_entities': [{'text': 'grupos', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'grupos de tratamiento',
#      'type': 'population'},
#     {'text': 'subvenciones', 'type': 'intervention'},
#     {'text': '$ 382', 'type': 'effect_size'},
#     {'text': 'miembro', 'type': 'coreference'}]},
#   {'sentence': 'Las entrevistas mostraron que todas las cuatro fuentes fueron influenciadas por la intervención .',
#    'expected_entities': [{'text': 'fuentes', 'type': 'coreference'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'intervención', 'type': 'intervention'}]},
#   {'sentence': 'Muchos de estos resultados observados parecen impulsados por la combinación de los dos programas .',
#    'expected_entities': [{'text': 'resultados', 'type': 'coreference'},
#     {'text': 'programas', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'estos resultados', 'type': 'coreference'},
#     {'text': 'los dos programas', 'type': 'coreference'}]},
#   {'sentence': 'Malas noticias : esto podría simplemente reflejar el hecho de que no se aplican .',
#    'expected_entities': [{'text': 'no', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'La identificación se basa en la variación inter temporal entre los grupos de tratamiento y control .',
#    'expected_entities': [{'text': 'grupos', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Análisis de esta cuestión es frustrado por la dificultad de distinguir tratamiento de efectos de selección .',
#    'expected_entities': [{'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Para 2002/2003 , aproximadamente la mitad de los distritos en el país se habían beneficiado del programa .',
#    'expected_entities': [{'text': 'beneficiado', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'la mitad de los distritos',
#      'type': 'population'},
#     {'text': 'programa', 'type': 'intervention'},
#     {'text': 'los distritos', 'type': 'coreference'}]},
#   {'sentence': 'Los análisis de este estudio se han realizado utilizando datos longitudinales de una encuesta de tratamiento aleatorizado y control .',
#    'expected_entities': [{'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Escuelas fueron asignadas aleatoriamente a ya sea la intervención ( n=50 ) o brazo de comparación ( n=50 ) .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Estudiamos cuánto de este problema puede resolverse utilizando una intervención multifacética que combina tres intervenciones conocidas por ser efectivas por separado .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'},
#     {'text': 'intervenciones', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'En 2 estados ( Veracruz y Chiapas ) 2 grupos de comunidades fueron asignados aleatoriamente a intervención o grupos de control .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Un experimento social aleatorizado por conglomerados se llevó a cabo en 2007 - 2009 para evaluar el impacto de este programa .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Se utilizó la regresión cuantílica para analizar el impacto heterogéneo del programa en los valores de la distribución de los resultados continuos .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'},
#     {'text': 'resultados', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Un inconveniente importante de estudios previos ha sido la participación selectiva en el programa , lo que lleva a estimaciones sesgadas de los efectos del programa .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'efectos', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'programa', 'type': 'intervention'},
#     {'text': 'estudios previos', 'type': 'coreference'}]},
#   {'sentence': 'Para medir el impacto del programa , implementamos un diseño de Discontinuidad en la Regresión ( RD ) en proyectos presentados para financiamiento entre 1988 y 1995 .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'En Ciudad del Cabo , Dar es Salaam y Mankweng , 26 , 24 y 30 escuelas , respectivamente , fueron asignadas aleatoriamente a intervención o grupos de comparación .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Diferencia porcentual - en - diferencias indican un desprendimiento significativo entre los esfuerzos tecnológicos del tratamiento y los grupos de control y permiten que la hipótesis de desplazamiento sea rechazada .',
#    'expected_entities': [{'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Evidencia de democracias establecidas sugiere que tales campañas son generalmente ineficaces , pero sigue siendo una pregunta abierta si lo mismo se aplica en elecciones bajo autoritarismo donde la información es escasa .',
#    'expected_entities': [{'text': 'campañas', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': "Una serie de modelos de regresión lineal , logística y logit ordenada multinivel son utilizados para estimar el efecto del tratamiento , con Hedges ' g y razones de probabilidades utilizadas para tamaños del efecto .",
#    'expected_entities': [{'text': 'efecto', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'tratamiento', 'type': 'intervention'},
#     {'text': "Hedges ' g", 'type': 'effect_size'},
#     {'text': 'razones de probabilidades', 'type': 'effect_size'}]},
#   {'sentence': 'Análisis primario , por intención de tratar , que involucra a todos los participantes asignados aleatoriamente ocurrió en pre - y postintervención y a los 3 meses de seguimiento ( grupo de intervención solamente ) .',
#    'expected_entities': [{'text': 'grupo', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Complementamos el análisis de tratamiento binario con el análisis de tratamiento continuo para entender no solo el impacto de estar en el programa sino también la variabilidad en los impactos según el grado de tratamiento .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'},
#     {'text': 'impactos', 'type': 'coreference'},
#     {'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Resultados Entre abril 2018 y octubre 2018 , 352 participantes ( n = 177 intervención , n = 175 control ) fueron inscritos y asignados aleatoriamente ; 312 ( 88.6% , n = 157 intervención , n = 155 control ) fueron retenidos a los 3 meses .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': '352 participantes', 'type': 'population'},
#     {'text': 'n = 177 intervención', 'type': 'intervention'},
#     {'text': 'n = 175 control', 'type': 'intervention'},
#     {'text': '312', 'type': 'outcome'},
#     {'text': '88.6%', 'type': 'effect_size'},
#     {'text': 'n = 157 intervención', 'type': 'intervention'},
#     {'text': 'n = 155 control', 'type': 'intervention'}]},
#   {'sentence': 'La media y desviación estándar de la CWS fueron 1.8 ( 1.9 ) para la intervención y 2.0 ( 1.9 ) para el grupo de control .',
#    'expected_entities': [{'text': 'CWS', 'type': 'outcome'},
#     {'text': '1.8', 'type': 'effect_size'},
#     {'text': '1.9', 'type': 'effect_size'},
#     {'text': 'intervención', 'type': 'coreference'},
#     {'text': '2.0', 'type': 'effect_size'},
#     {'text': '1.9', 'type': 'effect_size'}],
#    'predicted_entities': []},
#   {'sentence': 'Efectos del subsidio persisten en años posteriores sin subsidio .',
#    'expected_entities': [{'text': 'Efectos', 'type': 'coreference'},
#     {'text': 'subsidio', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'subsidio', 'type': 'intervention'},
#     {'text': 'años posteriores', 'type': 'coreference'}]},
#   {'sentence': 'La técnica se implementa en dos innovaciones en microfinanzas ugandesas , y medimos las formas en que los choques concurrentes como un brote de Ébola y una elección presidencial contenciosa alteraron los resultados de manera diferencial a través de regiones .',
#    'expected_entities': [{'text': 'innovaciones', 'type': 'coreference'},
#     {'text': 'microfinanzas', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'El efecto de la intervención fue solo sostenido en el grupo TNSB ( 98 [ 22 % ] de 450 compuestos ; 2.68 , 1.65 –4.34 ) .',
#    'expected_entities': [{'text': 'efecto de la intervención',
#      'type': 'coreference'},
#     {'text': 'TNSB', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'intervención', 'type': 'intervention'},
#     {'text': 'TNSB', 'type': 'population'},
#     {'text': 'compuestos', 'type': 'population'},
#     {'text': '22 %', 'type': 'effect_size'},
#     {'text': '450', 'type': 'population'},
#     {'text': '2.68', 'type': 'effect_size'},
#     {'text': '1.65', 'type': 'effect_size'},
#     {'text': '4.34', 'type': 'effect_size'}]},
#   {'sentence': 'La recolección de agua de lluvia in-situ no proporcionó ningún beneficio .',
#    'expected_entities': [{'text': 'recolección de agua de lluvia',
#      'type': 'intervention'},
#     {'text': 'beneficio', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Mejoradas estufas de cocción de biomasa se alega que contrarrestan estos efectos adversos .',
#    'expected_entities': [{'text': 'Mejoradas estufas de cocción de biomasa',
#      'type': 'intervention'},
#     {'text': 'efectos', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Este documento intenta investigar el impacto de las leyes salariales sectoriales en Sudáfrica .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'las leyes salariales sectoriales', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'La provisión de estaciones de lavado de manos por sí sola tuvo poco efecto .',
#    'expected_entities': [{'text': 'La provisión de estaciones de lavado de manos',
#      'type': 'intervention'},
#     {'text': 'efecto', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'provisión de estaciones de lavado de manos',
#      'type': 'intervention'},
#     {'text': 'la provisión', 'type': 'coreference'}]},
#   {'sentence': 'Resultados fueron evaluados después de aproximadamente 18 meses de uso de la nueva estufa .',
#    'expected_entities': [{'text': 'Resultados', 'type': 'coreference'},
#     {'text': 'la nueva estufa', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'Resultados', 'type': 'outcome'},
#     {'text': 'nueva estufa', 'type': 'intervention'}]},
#   {'sentence': 'Estos efectos se mitigan en cierta medida cuando los contratos se asignan a través de una subasta .',
#    'expected_entities': [{'text': 'efectos', 'type': 'coreference'},
#     {'text': 'contratos', 'type': 'intervention'},
#     {'text': 'una subasta', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'El documento estudia el efecto de una ley que prohibió el préstamo de microcréditos en el estado de Andhra Pradesh en India .',
#    'expected_entities': [{'text': 'efecto', 'type': 'coreference'},
#     {'text': 'ley que prohibió el préstamo de microcréditos',
#      'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'Varios documentos han discutido los efectos de adicionalidad o desplazamiento de las políticas de innovación que implican subvenciones y incentivos fiscales , por ejemplo .',
#    'expected_entities': [{'text': 'efectos', 'type': 'coreference'},
#     {'text': 'las políticas de innovación', 'type': 'intervention'},
#     {'text': 'subvenciones', 'type': 'intervention'},
#     {'text': 'incentivos fiscales', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'Nuestros resultados muestran que los impactos de adquisiciones extranjeras en China son diferentes de pero también comparables a aquellos en países desarrollados encontrados en la literatura .',
#    'expected_entities': [{'text': 'impactos', 'type': 'coreference'},
#     {'text': 'adquisiciones extranjeras', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'Methods : El grupo de intervención recibió Safe Delivery , que es una herramienta de capacitación en teléfonos inteligentes para la Atención Obstétrica y Neonatal de Emergencia .',
#    'expected_entities': [{'text': 'grupo', 'type': 'coreference'},
#     {'text': 'Safe Delivery', 'type': 'intervention'},
#     {'text': 'herramienta de capacitación en teléfonos inteligentes para la Atención Obstétrica y Neonatal de Emergencia',
#      'type': 'intervention'}],
#    'predicted_entities': [{'text': 'Safe Delivery', 'type': 'intervention'},
#     {'text': 'el grupo de intervención', 'type': 'population'},
#     {'text': 'Atención Obstétrica y Neonatal de Emergencia',
#      'type': 'outcome'}]},
#   {'sentence': 'Para controlar tales diferencias y permitir una interpretación causal del impacto de la adopción de NERICA , estimamos el Efecto de Tratamiento Promedio Local ( LATE ) .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'la adopción de NERICA', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'NERICA', 'type': 'intervention'},
#     {'text': 'Efecto de Tratamiento Promedio Local (LATE)',
#      'type': 'effect_size'},
#     {'text': 'la adopción de NERICA', 'type': 'intervention'}]},
#   {'sentence': 'Utilizamos una técnica de Emparejamiento de Puntuación de Propensión ( PSM ) y un modelo de Diferencia-en-Diferencia para estimar los efectos de la intervención de construcción de activos .',
#    'expected_entities': [{'text': 'efectos', 'type': 'coreference'},
#     {'text': 'intervención de construcción de activos',
#      'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'La presencia de una pariente femenina como una compañera de trabajo es una intervención preventiva de bajo costo , que es consistente con las prácticas culturales tradicionales en Botswana .',
#    'expected_entities': [{'text': 'presencia de una pariente femenina como una compañera de trabajo',
#      'type': 'intervention'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'una pariente femenina',
#      'type': 'intervention'},
#     {'text': 'compañera de trabajo', 'type': 'intervention'},
#     {'text': 'prácticas culturales tradicionales', 'type': 'coreference'},
#     {'text': 'Botswana', 'type': 'population'}]},
#   {'sentence': 'Estudios futuros deberían investigar si el mismo enfoque , cuando se entrega a través de medios masivos , puede tener un efecto similar al cara a cara entrega utilizado en este estudio .',
#    'expected_entities': [{'text': 'medios masivos', 'type': 'intervention'},
#     {'text': 'efecto', 'type': 'coreference'},
#     {'text': 'cara a cara entrega', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'Para combatir este problema , BRAC inició el programa multifacético Desafiando las Fronteras de la Reducción de la Pobreza con un enfoque basado en subvenciones , reforzando su eficacia con servicios de apoyo tales como salud y desarrollo social .',
#    'expected_entities': [{'text': 'Desafiando las Fronteras de la Reducción de la Pobreza',
#      'type': 'intervention'},
#     {'text': 'su', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Sin embargo , el impacto de estos acuerdos es en gran medida desconocido , ya que los estudios existentes a nivel micro entre el Norte ‐Norte y el Norte ‐Sur probablemente produzcan predicciones engañosas para los acuerdos comerciales Sur ‐Sur .',
#    'expected_entities': [{'text': 'impacto', 'type': 'coreference'},
#     {'text': 'acuerdos', 'type': 'coreference'},
#     {'text': 'acuerdos comerciales Sur ‐Sur', 'type': 'intervention'}],
#    'predicted_entities': []},
#   {'sentence': 'El grupo de tratamiento observó una prueba de contaminación del agua potable en su propio recipiente de almacenamiento doméstico ; mientras esperaban sus resultados , también se les proporcionó una lista de acciones que podrían tomar para remediar la contaminación si daban positivo .',
#    'expected_entities': [{'text': 'grupo', 'type': 'coreference'},
#     {'text': 'prueba de contaminación del agua potable',
#      'type': 'intervention'},
#     {'text': 'lista de acciones que podrían tomar para remediar la contaminación',
#      'type': 'intervention'}],
#    'predicted_entities': [{'text': 'grupo de tratamiento',
#      'type': 'population'},
#     {'text': 'prueba de contaminación del agua potable', 'type': 'outcome'},
#     {'text': 'recipiente de almacenamiento doméstico', 'type': 'coreference'},
#     {'text': 'sus resultados', 'type': 'coreference'},
#     {'text': 'acciones', 'type': 'coreference'},
#     {'text': 'contaminación', 'type': 'coreference'},
#     {'text': 'positivo', 'type': 'coreference'}]},
#   {'sentence': 'Método : La intervención , que duró nueve meses , consistió en el uso higiénico de orinales para la eliminación de heces de niños , desalentando a los niños de defecar alrededor de los hogares , construcción y uso de letrinas Mejoradas Ventiladas Económicas ( VIP ) y lavado de manos con jabón y agua por las madres después de limpiar las heces de los niños .',
#    'expected_entities': [{'text': 'intervención', 'type': 'coreference'},
#     {'text': 'el uso higiénico de orinales para la eliminación de heces de niños',
#      'type': 'intervention'},
#     {'text': 'desalentando a los niños de defecar alrededor de los hogares',
#      'type': 'intervention'},
#     {'text': 'construcción y uso de letrinas Mejoradas Ventiladas Económicas ( VIP )',
#      'type': 'intervention'},
#     {'text': 'lavado de manos con jabón y agua por las madres después de limpiar las heces de los niños',
#      'type': 'intervention'}],
#    'predicted_entities': [{'text': 'intervención', 'type': 'intervention'},
#     {'text': 'usar orinales', 'type': 'intervention'},
#     {'text': 'hogares', 'type': 'population'},
#     {'text': 'niños', 'type': 'population'},
#     {'text': 'construcción y uso de letrinas Mejoradas Ventiladas Económicas (VIP)',
#      'type': 'intervention'},
#     {'text': 'lavado de manos con jabón y agua', 'type': 'intervention'},
#     {'text': 'madres', 'type': 'population'}]},
#   {'sentence': 'Adherencia a la intervención fue variable durante el tiempo de seguimiento .',
#    'expected_entities': [{'text': 'Adherencia', 'type': 'outcome'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'intervención', 'type': 'intervention'},
#     {'text': 'tiempo de seguimiento', 'type': 'coreference'}]},
#   {'sentence': 'Un marco de regresión de mínimos cuadrados ordinarios fue utilizado para estimar la diferencia en diferencia del ingreso entre los hogares de control y los hogares de tratamiento .',
#    'expected_entities': [{'text': 'ingreso', 'type': 'outcome'},
#     {'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'ingreso', 'type': 'outcome'},
#     {'text': 'hogares de control', 'type': 'population'},
#     {'text': 'hogares de tratamiento', 'type': 'population'}]},
#   {'sentence': 'Los hallazgos mostraron diferencias significativas ( p < 0.05 ) entre los grupos experimental y de control en todas las subvariables de creatividad , y los resultados se mantuvieron en la evaluación de seguimiento de dos meses .',
#    'expected_entities': [{'text': 'experimental', 'type': 'coreference'},
#     {'text': 'creatividad', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'los hallazgos', 'type': 'outcome'},
#     {'text': 'diferencias significativas', 'type': 'effect_size'},
#     {'text': 'grupos experimental y de control', 'type': 'population'},
#     {'text': 'subvariables de creatividad', 'type': 'outcome'},
#     {'text': 'resultados', 'type': 'outcome'},
#     {'text': 'evaluación de seguimiento de dos meses', 'type': 'population'}]},
#   {'sentence': 'Trabajadores de campo visitaron hogares al menos una vez a la semana desde abril hasta diciembre de 2003 para promover el uso de las intervenciones y para recopilar datos sobre diarrea .',
#    'expected_entities': [{'text': 'las intervenciones', 'type': 'coreference'},
#     {'text': 'diarrea', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'trabajadores de campo',
#      'type': 'intervention'},
#     {'text': 'hogares', 'type': 'population'},
#     {'text': 'diarrea', 'type': 'outcome'}]},
#   {'sentence': 'Ambos enfoques aumentaron la inscripción y la asistencia .',
#    'expected_entities': [{'text': 'enfoques', 'type': 'coreference'},
#     {'text': 'la inscripción y la asistencia', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'Ambos enfoques', 'type': 'intervention'},
#     {'text': 'la inscripción', 'type': 'outcome'},
#     {'text': 'la asistencia', 'type': 'outcome'}]},
#   {'sentence': 'Sin embargo , el programa ha reducido la tasa de pobreza de los participantes .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'tasa de pobreza', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el programa', 'type': 'intervention'},
#     {'text': 'los participantes', 'type': 'population'},
#     {'text': 'la tasa de pobreza', 'type': 'outcome'}]},
#   {'sentence': 'Hemos documentado los efectos del programa sobre el crecimiento y la reducción de anemia .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'el crecimiento', 'type': 'outcome'},
#     {'text': 'anemia', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'programa', 'type': 'intervention'},
#     {'text': 'crecimiento', 'type': 'outcome'},
#     {'text': 'anemia', 'type': 'outcome'}]},
#   {'sentence': 'Ambas intervenciones redujeron la prevalencia posparto de al menos cuatro deposiciones sueltas y ceguera nocturna .',
#    'expected_entities': [{'text': 'intervenciones', 'type': 'coreference'},
#     {'text': 'deposiciones sueltas', 'type': 'outcome'},
#     {'text': 'ceguera nocturna', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'Ambas intervenciones',
#      'type': 'intervention'},
#     {'text': 'la prevalencia posparto', 'type': 'outcome'},
#     {'text': 'de al menos cuatro deposiciones sueltas y ceguera nocturna',
#      'type': 'effect_size'}]},
#   {'sentence': 'Análisis de regresión indicaron que el miedo al contacto casual fue reducido por la intervención .',
#    'expected_entities': [{'text': 'el miedo al contacto casual',
#      'type': 'outcome'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'el miedo al contacto casual',
#      'type': 'outcome'},
#     {'text': 'intervención', 'type': 'intervention'}]},
#   {'sentence': 'El resultado primario fue el clima escolar medido con el Cuestionario de Clima Escolar Beyond Blue ( BBSCQ ) .',
#    'expected_entities': [{'text': 'primario', 'type': 'coreference'},
#     {'text': 'clima escolar', 'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'Sin embargo , no hubo ninguna diferencia significativa en las puntuaciones de cumplimiento obtenidas 1 mes después de la intervención .',
#    'expected_entities': [{'text': 'puntuaciones de cumplimiento',
#      'type': 'outcome'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'intervención', 'type': 'intervention'},
#     {'text': 'puntuaciones de cumplimiento', 'type': 'outcome'},
#     {'text': '1 mes después de la intervención', 'type': 'coreference'}]},
#   {'sentence': 'La ley ha causado una reducción en las tasas de interés y un aumento en el volumen de crédito personal .',
#    'expected_entities': [{'text': 'ley', 'type': 'coreference'},
#     {'text': 'las tasas de interés', 'type': 'outcome'},
#     {'text': 'volumen de crédito personal', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'la ley', 'type': 'intervention'},
#     {'text': 'tasas de interés', 'type': 'outcome'},
#     {'text': 'volumen de crédito personal', 'type': 'outcome'}]},
#   {'sentence': 'Sin embargo , contrariamente a lo esperado , la proporción de cultivos de alta intensidad de agua también aumenta con la participación .',
#    'expected_entities': [{'text': 'proporción de cultivos de alta intensidad de agua',
#      'type': 'outcome'},
#     {'text': 'la', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'En general , se encontraron pocos efectos , y en algunos casos se encontraron efectos que uno asociaría con una calidad escolar reducida .',
#    'expected_entities': [{'text': 'efectos', 'type': 'coreference'},
#     {'text': 'efectos', 'type': 'coreference'},
#     {'text': 'calidad escolar reducida', 'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'En teoría , el programa crea una trampa de pobreza , con una tasa de retiro de beneficios del 100% ( BWR ) .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'trampa de pobreza', 'type': 'outcome'},
#     {'text': 'tasa de retiro de beneficios del 100% ( BWR )',
#      'type': 'outcome'}],
#    'predicted_entities': [{'text': 'programa', 'type': 'intervention'},
#     {'text': 'trampa de pobreza', 'type': 'outcome'},
#     {'text': '100%', 'type': 'effect_size'},
#     {'text': 'BWR', 'type': 'outcome'}]},
#   {'sentence': 'Vemos efectos mayores en los lugares menos seguros , especialmente para las percepciones de seguridad a corto plazo , robos de autos , y asaltos .',
#    'expected_entities': [{'text': 'efectos', 'type': 'coreference'},
#     {'text': 'percepciones de seguridad a corto plazo', 'type': 'outcome'},
#     {'text': 'robos de autos', 'type': 'outcome'},
#     {'text': 'asaltos', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'los lugares menos seguros',
#      'type': 'population'},
#     {'text': 'percepciones de seguridad a corto plazo', 'type': 'outcome'},
#     {'text': 'robos de autos', 'type': 'outcome'},
#     {'text': 'asaltos', 'type': 'outcome'},
#     {'text': 'mayores', 'type': 'effect_size'}]},
#   {'sentence': 'Para evaluar el sesgo de información , nosotros también recopilamos datos sobre resultados de salud que no se espera que sean afectados por nuestras intervenciones .',
#    'expected_entities': [{'text': 'resultados de salud', 'type': 'outcome'},
#     {'text': 'intervenciones', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Los resultados mostraron que ambas intervenciones fueron igualmente efectivas en mejorar los niveles de conocimiento de los prescriptores sobre el manejo adecuado de la diarrea aguda .',
#    'expected_entities': [{'text': 'intervenciones', 'type': 'coreference'},
#     {'text': 'niveles de conocimiento de los prescriptores sobre el manejo adecuado de la diarrea aguda',
#      'type': 'outcome'}],
#    'predicted_entities': [{'text': 'ambas intervenciones',
#      'type': 'intervention'},
#     {'text': 'niveles de conocimiento', 'type': 'outcome'},
#     {'text': 'prescriptores', 'type': 'population'},
#     {'text': 'manejo adecuado de la diarrea aguda', 'type': 'intervention'}]},
#   {'sentence': 'Estas intervenciones no tuvieron ningún impacto en la participación de la comunidad , el esfuerzo del profesor , o los resultados de aprendizaje dentro de la escuela .',
#    'expected_entities': [{'text': 'intervenciones', 'type': 'coreference'},
#     {'text': 'la participación de la comunidad', 'type': 'outcome'},
#     {'text': 'el esfuerzo del profesor', 'type': 'outcome'},
#     {'text': 'los resultados de aprendizaje dentro de la escuela',
#      'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'Sin embargo , el número de actividades empresariales y empleados en el grupo de tratamiento disminuyó en relación con los controles , y el bienestar subjetivo disminuyó ligeramente .',
#    'expected_entities': [{'text': 'número de actividades empresariales',
#      'type': 'outcome'},
#     {'text': 'empleados', 'type': 'outcome'},
#     {'text': 'grupo', 'type': 'coreference'},
#     {'text': 'el bienestar subjetivo', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el número de actividades empresariales y empleados',
#      'type': 'outcome'},
#     {'text': 'grupo de tratamiento', 'type': 'population'},
#     {'text': 'los controles', 'type': 'population'},
#     {'text': 'el bienestar subjetivo', 'type': 'outcome'}]},
#   {'sentence': 'Ellos también usaron parámetros estimados de el estudio para simular costo - por- persona de el programa cuando el aumento de participación incrementa ( ganancias de eficiencia ) .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'el aumento de participación', 'type': 'outcome'},
#     {'text': 'ganancias de eficiencia', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el estudio', 'type': 'coreference'},
#     {'text': 'el programa', 'type': 'coreference'},
#     {'text': 'participación', 'type': 'intervention'},
#     {'text': 'ganancias de eficiencia', 'type': 'outcome'}]},
#   {'sentence': 'El investigador también evaluó HW / GW mediante observación directa a 1 mes antes de la intervención , durante el período de intervención , y 1 mes después de la intervención .',
#    'expected_entities': [{'text': 'HW / GW', 'type': 'outcome'},
#     {'text': 'período', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'HW / GW', 'type': 'outcome'},
#     {'text': 'intervención', 'type': 'intervention'},
#     {'text': '1 mes antes de la intervención', 'type': 'coreference'},
#     {'text': 'durante el período de intervención', 'type': 'coreference'},
#     {'text': '1 mes después de la intervención', 'type': 'coreference'}]},
#   {'sentence': 'El análisis cualitativo sugiere que un mecanismo clave por el cual el programa mejoró el acceso a los derechos fue permitir a los hogares objetivo eludir a los intermediarios que buscan rentas .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'el acceso a los derechos', 'type': 'outcome'},
#     {'text': 'eludir a los intermediarios que buscan rentas',
#      'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el programa', 'type': 'intervention'},
#     {'text': 'acceso a los derechos', 'type': 'outcome'},
#     {'text': 'hogares objetivo', 'type': 'population'}]},
#   {'sentence': 'Conclusiones : En uno de los pocos esfuerzos para promover la limpieza compartida de baños , los compuestos de intervención fueron significativamente más propensos a tener baños más limpios después de seis meses .',
#    'expected_entities': [{'text': 'la limpieza compartida de baños',
#      'type': 'outcome'},
#     {'text': 'los', 'type': 'coreference'},
#     {'text': 'baños más limpios', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'compuestos de intervención',
#      'type': 'intervention'},
#     {'text': 'baños', 'type': 'outcome'},
#     {'text': 'seis meses', 'type': 'coreference'}]},
#   {'sentence': 'Aunque el programa ha demostrado su potencial , es demasiado temprano para concluir si los beneficios acumulados son lo suficientemente grandes para contener tanto la pobreza estacional como la pobreza crónica de manera sostenida .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'la pobreza estacional', 'type': 'outcome'},
#     {'text': 'pobreza crónica', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el programa', 'type': 'intervention'},
#     {'text': 'beneficios', 'type': 'outcome'},
#     {'text': 'pobreza estacional', 'type': 'outcome'},
#     {'text': 'pobreza crónica', 'type': 'outcome'}]},
#   {'sentence': 'El objetivo del presente estudio fue construir sobre los hallazgos de este ensayo investigando prospectivamente los factores psicológicos que estaban más fuertemente asociados con cambiar a pozos seguros de arsénico en respuesta a estas intervenciones .',
#    'expected_entities': [{'text': 'cambiar a pozos seguros de arsénico',
#      'type': 'outcome'},
#     {'text': 'intervenciones', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'este ensayo', 'type': 'coreference'},
#     {'text': 'factores psicológicos', 'type': 'outcome'},
#     {'text': 'cambiando a pozos seguros de arsénico', 'type': 'intervention'},
#     {'text': 'estas intervenciones', 'type': 'coreference'}]},
#   {'sentence': 'Nosotros encontramos que el proyecto aumentó la participación en las asambleas del pueblo y la frecuencia con la que los funcionarios locales se reúnen con los residentes y tuvo un impacto negativo en la acción colectiva .',
#    'expected_entities': [{'text': 'proyecto', 'type': 'coreference'},
#     {'text': 'la participación en las asambleas del pueblo',
#      'type': 'outcome'},
#     {'text': 'frecuencia con la que los funcionarios locales se reúnen con los residentes',
#      'type': 'outcome'},
#     {'text': 'impacto', 'type': 'coreference'},
#     {'text': 'la acción colectiva', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'proyecto', 'type': 'intervention'},
#     {'text': 'participación en las asambleas del pueblo', 'type': 'outcome'},
#     {'text': 'funcionarios locales', 'type': 'population'},
#     {'text': 'residentes', 'type': 'population'},
#     {'text': 'acción colectiva', 'type': 'outcome'}]},
#   {'sentence': 'Curiosamente , el análisis ANOVA de parcelas divididas mostró que los términos de interacción de grupos y tratamiento fueron significativos , donde el tratamiento para grupos experimentales fue significativamente menor en comportamiento sedentario después del tratamiento .',
#    'expected_entities': [{'text': 'tratamiento', 'type': 'coreference'},
#     {'text': 'tratamiento', 'type': 'coreference'},
#     {'text': 'comportamiento sedentario', 'type': 'outcome'},
#     {'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'parcelas divididas',
#      'type': 'coreference'},
#     {'text': 'grupos', 'type': 'population'},
#     {'text': 'tratamiento', 'type': 'intervention'},
#     {'text': 'comportamiento sedentario', 'type': 'outcome'},
#     {'text': 'tratamiento', 'type': 'coreference'}]},
#   {'sentence': 'Nosotros usamos una lista de espera aleatorizada controlada en cuatro municipios en un Estado del sur de Brasil ( Santa Catarina ) para cuantificar los efectos del programa sobre la progresión escolar , resultados del mercado laboral y habilidades no cognitivas .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'la progresión escolar', 'type': 'outcome'},
#     {'text': 'resultados del mercado laboral', 'type': 'outcome'},
#     {'text': 'habilidades no cognitivas', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'una lista de espera aleatorizada controlada',
#      'type': 'intervention'},
#     {'text': 'cuatro municipios', 'type': 'population'},
#     {'text': 'Santa Catarina', 'type': 'population'},
#     {'text': 'el programa', 'type': 'coreference'},
#     {'text': 'progresión escolar', 'type': 'outcome'},
#     {'text': 'resultados del mercado laboral', 'type': 'outcome'},
#     {'text': 'habilidades no cognitivas', 'type': 'outcome'}]},
#   {'sentence': 'El estudio investigó el impacto de la capacitación en las prácticas de prescripción para dos condiciones objetivo , en un grupo de control y un grupo de estudio de 11 clínicas cada una , 1 mes después y 3 meses después de la intervención .',
#    'expected_entities': [{'text': 'capacitación', 'type': 'coreference'},
#     {'text': 'las prácticas de prescripción', 'type': 'outcome'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'capacitación', 'type': 'intervention'},
#     {'text': 'prácticas de prescripción', 'type': 'outcome'},
#     {'text': 'dos condiciones objetivo', 'type': 'outcome'},
#     {'text': 'grupo de control', 'type': 'population'},
#     {'text': 'grupo de estudio', 'type': 'population'},
#     {'text': '11 clínicas', 'type': 'population'},
#     {'text': '1 mes después', 'type': 'coreference'},
#     {'text': '3 meses después', 'type': 'coreference'},
#     {'text': 'intervención', 'type': 'coreference'}]},
#   {'sentence': 'La estrategia de identificación utilizada en este documento explota la variación temporal y espacial en el despliegue de fuerzas policiales y la estructura del crimen organizado de la actividad criminal en Río de Janeiro para evaluar el efecto causal del programa sobre la actividad criminal .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'la actividad criminal', 'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'Los experimentos de encuesta entre individuos en comunidades tratadas y de control ( N = 5,560 ) sugieren que las personas en las aldeas tratadas son de hecho más propensas a sancionar a los de bajo rendimiento y votar basándose en el rendimiento con más frecuencia .',
#    'expected_entities': [{'text': 'tratadas', 'type': 'coreference'},
#     {'text': 'tratadas', 'type': 'coreference'},
#     {'text': 'sancionar a los de bajo rendimiento', 'type': 'outcome'},
#     {'text': 'votar basándose en el rendimiento', 'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'Nosotros entonces directamente probamos si el programa ha inducido cambios significativos en las elasticidades del gasto ( como se implica por sus propensiones marginales asociadas a consumir ) y encontramos evidencia de esto para alcohol y tabaco , y en menor medida para alimentos , salud y transporte y comunicación .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'las elasticidades del gasto', 'type': 'outcome'},
#     {'text': 'alcohol y tabaco', 'type': 'outcome'},
#     {'text': 'alimentos', 'type': 'outcome'},
#     {'text': 'salud', 'type': 'outcome'},
#     {'text': 'transporte', 'type': 'outcome'},
#     {'text': 'comunicación', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'el programa', 'type': 'intervention'},
#     {'text': 'elasticidades del gasto', 'type': 'outcome'},
#     {'text': 'consumir', 'type': 'coreference'},
#     {'text': 'alcohol', 'type': 'outcome'},
#     {'text': 'tabaco', 'type': 'outcome'},
#     {'text': 'alimentos', 'type': 'outcome'},
#     {'text': 'salud', 'type': 'outcome'},
#     {'text': 'transporte y comunicación', 'type': 'outcome'}]},
#   {'sentence': 'El resultado principal , incidencia de HWWS después de un evento de uso del inodoro , se comparó entre los grupos de intervención en diferentes puntos de recolección de datos con análisis de regresión de Poisson robusto con ecuaciones de estimación generalizadas , ajustando por agrupamiento a nivel escolar de los resultados .',
#    'expected_entities': [{'text': 'incidencia de HWWS después de un evento de uso del inodoro',
#      'type': 'outcome'},
#     {'text': 'grupos', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Eso llevó a una mejora en la estructura de activos , mayor acceso a ganado , micro máquinas , riqueza familiar y ahorros familiares , toma de decisiones educativas , mejorada movilidad , habilidades de comunicación , expresión de preocupaciones , autoconfianza , mayor participación política para promover la igualdad de género , etc .',
#    'expected_entities': [{'text': 'Eso', 'type': 'coreference'},
#     {'text': 'la estructura de activos', 'type': 'outcome'},
#     {'text': 'acceso a ganado', 'type': 'outcome'},
#     {'text': 'micro máquinas', 'type': 'outcome'},
#     {'text': 'riqueza familiar', 'type': 'outcome'},
#     {'text': 'ahorros familiares', 'type': 'outcome'},
#     {'text': 'toma de decisiones educativas', 'type': 'outcome'},
#     {'text': 'movilidad', 'type': 'outcome'},
#     {'text': 'habilidades de comunicación', 'type': 'outcome'},
#     {'text': 'expresión de preocupaciones', 'type': 'outcome'},
#     {'text': 'autoconfianza', 'type': 'outcome'},
#     {'text': 'participación política', 'type': 'outcome'},
#     {'text': 'la igualdad de género', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'estructura de activos', 'type': 'outcome'},
#     {'text': 'acceso a ganado', 'type': 'outcome'},
#     {'text': 'micro máquinas', 'type': 'outcome'},
#     {'text': 'riqueza familiar', 'type': 'outcome'},
#     {'text': 'ahorros familiares', 'type': 'outcome'},
#     {'text': 'toma de decisiones educativas', 'type': 'outcome'},
#     {'text': 'movilidad', 'type': 'outcome'},
#     {'text': 'habilidades de comunicación', 'type': 'outcome'},
#     {'text': 'expresión de preocupaciones', 'type': 'outcome'},
#     {'text': 'autoconfianza', 'type': 'outcome'},
#     {'text': 'participación política', 'type': 'outcome'},
#     {'text': 'promover la igualdad de género', 'type': 'outcome'}]},
#   {'sentence': 'Análisis cuantitativos y cualitativos revelaron las percepciones de los estudiantes sobre la efectividad del programa .',
#    'expected_entities': [{'text': 'las', 'type': 'population'},
#     {'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'De los previstos 1000 hogares , 465 tratamientos y 325 controles participaron en la encuesta inicial .',
#    'expected_entities': [{'text': 'hogares', 'type': 'population'},
#     {'text': 'tratamientos', 'type': 'coreference'}],
#    'predicted_entities': [{'text': '1000 hogares', 'type': 'population'},
#     {'text': '465 tratamientos', 'type': 'intervention'},
#     {'text': '325 controles', 'type': 'intervention'},
#     {'text': 'la encuesta inicial', 'type': 'outcome'},
#     {'text': 'participaron', 'type': 'coreference'}]},
#   {'sentence': 'Un experimental y un grupo de control fueron formados al asignar aleatoriamente a los estudiantes a uno de los dos grupos .',
#    'expected_entities': [{'text': 'experimental', 'type': 'coreference'},
#     {'text': 'estudiantes', 'type': 'population'}],
#    'predicted_entities': []},
#   {'sentence': 'Niñas fueron divididas en 31 grupos , con 457 y 462 participantes asignadas a el intervención y control grupos , respectivamente .',
#    'expected_entities': [{'text': 'Niñas', 'type': 'population'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'Niñas', 'type': 'population'},
#     {'text': '31 grupos', 'type': 'coreference'},
#     {'text': '457 y 462 participantes', 'type': 'coreference'},
#     {'text': 'intervención', 'type': 'intervention'},
#     {'text': 'control grupos', 'type': 'coreference'}]},
#   {'sentence': 'El análisis se basa en un diseño de investigación cuasi-experimental que incluye aproximadamente cuatrocientos niños en tratamiento y comunidades de control comparables .',
#    'expected_entities': [{'text': 'niños', 'type': 'population'},
#     {'text': 'tratamiento', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Usando estimadores de regresión de doble diferencia en datos recopilados antes y después del programa para " control " y " tratamiento " hogares , los impactos relativos de los componentes del programa del lado de la demanda y la oferta son estimados .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'tratamiento', 'type': 'coreference'},
#     {'text': 'hogares', 'type': 'population'},
#     {'text': 'impactos', 'type': 'coreference'},
#     {'text': 'programa', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Nosotros también encontramos poca evidencia de que los efectos del tratamiento fueran más pronunciados para mujeres .',
#    'expected_entities': [{'text': 'los efectos del tratamiento',
#      'type': 'coreference'},
#     {'text': 'mujeres', 'type': 'population'}],
#    'predicted_entities': [{'text': 'los efectos del tratamiento',
#      'type': 'effect_size'},
#     {'text': 'mujeres', 'type': 'population'}]},
#   {'sentence': 'Los participantes ( N = 337 , 94 % mujeres ) fueron asignados aleatoriamente a un grupo experimental o un grupo de control .',
#    'expected_entities': [{'text': 'mujeres', 'type': 'population'},
#     {'text': 'grupo experimental', 'type': 'coreference'}],
#    'predicted_entities': []},
#   {'sentence': 'Noventa y seis niños fueron asignados aleatoriamente a la intervención ( n = 49 ) y grupos de control ( n = 47 ) .',
#    'expected_entities': [{'text': 'niños', 'type': 'population'},
#     {'text': 'la intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'Noventa y seis niños',
#      'type': 'population'},
#     {'text': 'intervención', 'type': 'intervention'},
#     {'text': 'n = 49', 'type': 'outcome'},
#     {'text': 'grupos de control', 'type': 'population'},
#     {'text': 'n = 47', 'type': 'outcome'}]},
#   {'sentence': 'Niño y cuidador díadas fueron aleatorizadas a un grupo de control , intervención solo para niños , niño + cuidador intervención , o niño + cuidador + comunidad intervención .',
#    'expected_entities': [{'text': 'Niño', 'type': 'population'},
#     {'text': 'cuidador', 'type': 'population'},
#     {'text': 'intervención solo para niños', 'type': 'coreference'},
#     {'text': 'niño', 'type': 'population'},
#     {'text': 'cuidador', 'type': 'population'},
#     {'text': 'intervención', 'type': 'coreference'},
#     {'text': 'niño', 'type': 'population'},
#     {'text': 'cuidador', 'type': 'population'},
#     {'text': 'comunidad', 'type': 'population'},
#     {'text': 'intervención', 'type': 'coreference'}],
#    'predicted_entities': [{'text': 'Niño y cuidador díadas',
#      'type': 'population'},
#     {'text': 'grupo de control', 'type': 'intervention'},
#     {'text': 'intervención solo para niños', 'type': 'intervention'},
#     {'text': 'niño + cuidador intervención', 'type': 'intervention'},
#     {'text': 'niño + cuidador + comunidad intervención',
#      'type': 'intervention'},
#     {'text': 'Niño y cuidador díadas', 'type': 'coreference'},
#     {'text': 'grupos de control', 'type': 'coreference'},
#     {'text': 'intervención solo para niños', 'type': 'coreference'},
#     {'text': 'niño + cuidador intervención', 'type': 'coreference'},
#     {'text': 'niño + cuidador + comunidad intervención',
#      'type': 'coreference'}]},
#   {'sentence': 'Población : 146 parteras fueron asignadas aleatoriamente a la intervención ( 70 parteras , siete hospitales , 1,665 partos ) o al grupo de control ( 76 parteras , ocho hospitales , 1,746 partos ) .',
#    'expected_entities': [{'text': 'parteras', 'type': 'population'},
#     {'text': 'la intervención', 'type': 'coreference'},
#     {'text': 'parteras', 'type': 'population'},
#     {'text': 'parteras', 'type': 'population'}],
#    'predicted_entities': [{'text': '146 parteras', 'type': 'population'},
#     {'text': '1,665 partos', 'type': 'outcome'},
#     {'text': '70 parteras', 'type': 'intervention'},
#     {'text': '76 parteras', 'type': 'population'},
#     {'text': '8 hospitales', 'type': 'population'},
#     {'text': '1,746 partos', 'type': 'outcome'},
#     {'text': 'la intervención', 'type': 'intervention'},
#     {'text': 'el grupo de control', 'type': 'population'},
# ...
#     {'text': 'la regulación ambiental', 'type': 'intervention'},
#     {'text': 'el emprendimiento', 'type': 'outcome'},
#     {'text': 'industrias intensivas en contaminación', 'type': 'population'}],
#    'predicted_entities': [{'text': 'política de las Dos Zonas de Control de China en 1998',
#      'type': 'intervention'},
#     {'text': 'creación de empresas', 'type': 'outcome'},
#     {'text': 'regulación ambiental', 'type': 'intervention'},
#     {'text': 'industrias intensivas en contaminación', 'type': 'population'},
#     {'text': 'diferencias - en - diferencias - en - diferencias',
#      'type': 'effect_size'}]},
#   {'sentence': "Conclusiones : Un programa de 18 meses de enseñanza y aprendizaje remedial suplementario de materiales tuvo un impacto sustancial en las puntuaciones de lenguaje y matemáticas de estudiantes de escuelas primarias en Andhra Pradesh rural , sin embargo proporcionar un ' kit ' de materiales a niñas en estas aldeas no condujo a ningún beneficio adicional medido .",
#    'expected_entities': [{'text': 'de enseñanza y aprendizaje remedial suplementario de materiales',
#      'type': 'intervention'},
#     {'text': 'las puntuaciones de lenguaje y matemáticas', 'type': 'outcome'},
#     {'text': 'estudiantes de escuelas primarias', 'type': 'population'},
#     {'text': 'Andhra Pradesh rural', 'type': 'population'},
#     {'text': "proporcionar un ' kit ' de materiales", 'type': 'intervention'},
#     {'text': 'niñas', 'type': 'population'}],
#    'predicted_entities': [{'text': 'Un programa de 18 meses de enseñanza y aprendizaje remedial suplementario de materiales',
#      'type': 'intervention'},
#     {'text': 'estudiantes de escuelas primarias', 'type': 'population'},
#     {'text': 'Andhra Pradesh rural', 'type': 'population'},
#     {'text': 'puntuaciones de lenguaje y matemáticas', 'type': 'outcome'},
#     {'text': 'niñas', 'type': 'population'},
#     {'text': 'kit de materiales', 'type': 'intervention'},
#     {'text': 'beneficio adicional', 'type': 'outcome'}]},
#   {'sentence': 'Ingestas medias de energía , proteína , carbohidratos , ácido docosahexaenoico , ácido araquidónico , calcio , fósforo , hierro , zinc , y vitaminas A , C , D , E , y B6 fueron significativamente más altas en el grupo NC + NS a los días 60 y 120 ( todos P < 0.01 ) .',
#    'expected_entities': [{'text': 'Ingestas medias de energía , proteína , carbohidratos , ácido docosahexaenoico , ácido araquidónico , calcio , fósforo , hierro , zinc , y vitaminas A , C , D , E , y B6',
#      'type': 'outcome'},
#     {'text': 'NC + NS', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'ingestas medias de energía',
#      'type': 'outcome'},
#     {'text': 'proteína', 'type': 'outcome'},
#     {'text': 'carbohidratos', 'type': 'outcome'},
#     {'text': 'ácido docosahexaenoico', 'type': 'outcome'},
#     {'text': 'ácido araquidónico', 'type': 'outcome'},
#     {'text': 'calcio', 'type': 'outcome'},
#     {'text': 'fósforo', 'type': 'outcome'},
#     {'text': 'hierro', 'type': 'outcome'},
#     {'text': 'zinc', 'type': 'outcome'},
#     {'text': 'vitaminas A', 'type': 'outcome'},
#     {'text': 'vitaminas C', 'type': 'outcome'},
#     {'text': 'vitaminas D', 'type': 'outcome'},
#     {'text': 'vitaminas E', 'type': 'outcome'},
#     {'text': 'vitaminas B6', 'type': 'outcome'},
#     {'text': 'NC + NS', 'type': 'intervention'},
#     {'text': 'días 60 y 120', 'type': 'population'},
#     {'text': 'todos P < 0.01', 'type': 'effect_size'}]},
#   {'sentence': "Basándonos en el enfoque de capacidades , la teoría cognitiva social , y la teoría del aprendizaje experiencial , presentamos el primer estudio experimental en Asia Central que prueba el efecto de un programa educativo experiencial sobre las adolescentes ' agencia personal , incluyendo la autoeficacia , la orientación hacia el futuro , y el locus de control .",
#    'expected_entities': [{'text': 'estudio', 'type': 'coreference'},
#     {'text': 'programa educativo experiencial', 'type': 'intervention'},
#     {'text': 'las adolescentes', 'type': 'population'},
#     {'text': 'agencia personal ,', 'type': 'outcome'},
#     {'text': 'la autoeficacia', 'type': 'outcome'},
#     {'text': 'la orientación hacia el futuro', 'type': 'outcome'},
#     {'text': 'el locus de control', 'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'La probabilidad acumulada de infección por VIH - 1 a los 24 meses fue del 36.7% ( intervalo de confianza del 95% [ IC ] , 29.4% - 44.0% ) en el grupo de lactancia materna y del 20.5% ( IC del 95% , 14.0% - 27.0% ) en el grupo de fórmula ( P = .001 ) .',
#    'expected_entities': [{'text': 'probabilidad acumulada de infección por VIH - 1',
#      'type': 'outcome'},
#     {'text': 'del 36.7%', 'type': 'effect_size'},
#     {'text': 'grupo de lactancia materna', 'type': 'intervention'},
#     {'text': 'del 20.5%', 'type': 'effect_size'}],
#    'predicted_entities': []},
#   {'sentence': 'Nosotros evaluamos el impacto de pagos autenticados biométricamente infraestructura ( “ Tarjetas Inteligentes ” ) sobre beneficiarios de empleo ( NREGS ) y programas de pensiones ( SSP ) en el estado indio de Andhra Pradesh , utilizando un experimento a gran escala que aleatorizó el despliegue de Tarjetas Inteligentes sobre 157 subdistritos y 19 millones de personas .',
#    'expected_entities': [{'text': 'pagos autenticados biométricamente infraestructura ( “ Tarjetas Inteligentes ” )',
#      'type': 'intervention'},
#     {'text': 'beneficiarios de empleo ( NREGS ) y programas de pensiones ( SSP )',
#      'type': 'population'},
#     {'text': 'Tarjetas Inteligentes', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'Tarjetas Inteligentes',
#      'type': 'intervention'},
#     {'text': 'beneficiarios de empleo (NREGS)', 'type': 'population'},
#     {'text': 'programas de pensiones (SSP)', 'type': 'population'},
#     {'text': 'Andhra Pradesh', 'type': 'population'},
#     {'text': '157 subdistritos', 'type': 'population'},
#     {'text': '19 millones de personas', 'type': 'population'}]},
#   {'sentence': 'Hallazgos - El programa ha sido encontrado que tiene éxito en impactar sobre componentes físicos , económicos y políticos del empoderamiento , pero ha fallado en expandir espacios socioculturales de cuatro comunidades socio - religiosas ( SRCs ) a saber , castas superiores , otras castas atrasadas , castas registradas ( SCs ) y musulmanes ( Ms ) .',
#    'expected_entities': [{'text': 'programa', 'type': 'coreference'},
#     {'text': 'componentes físicos , económicos y políticos del empoderamiento',
#      'type': 'outcome'},
#     {'text': 'espacios socioculturales', 'type': 'outcome'},
#     {'text': 'comunidades socio - religiosas ( SRCs )', 'type': 'population'},
#     {'text': 'castas superiores', 'type': 'population'},
#     {'text': 'castas atrasadas', 'type': 'population'},
#     {'text': 'castas registradas ( SCs )', 'type': 'population'},
#     {'text': 'musulmanes ( Ms )', 'type': 'population'}],
#    'predicted_entities': [{'text': 'programa', 'type': 'intervention'},
#     {'text': 'componentes físicos', 'type': 'outcome'},
#     {'text': 'componentes económicos', 'type': 'outcome'},
#     {'text': 'componentes políticos', 'type': 'outcome'},
#     {'text': 'espacios socioculturales', 'type': 'outcome'},
#     {'text': 'cuatro comunidades socio - religiosas', 'type': 'population'},
#     {'text': 'castas superiores', 'type': 'population'},
#     {'text': 'otras castas atrasadas', 'type': 'population'},
#     {'text': 'castas registradas ( SCs )', 'type': 'population'},
#     {'text': 'musulmanes ( Ms )', 'type': 'population'}]},
#   {'sentence': 'Niños en aldeas CLTS eran más altos ( 0.18 aumento en altura - para la edad Z puntuación , 95 % IC 0.03 - 0.32 ; 2415 niños ) y menos propensos a estar retrasados ( 35 % frente a 41 % , RP 0.86 , 95 % IC 0.74 -1.0 ) que niños en aldeas de control .',
#    'expected_entities': [{'text': 'Niños', 'type': 'population'},
#     {'text': 'aldeas CLTS', 'type': 'intervention'},
#     {'text': 'más altos', 'type': 'outcome'},
#     {'text': '0.18', 'type': 'effect_size'},
#     {'text': 'altura - para la edad', 'type': 'outcome'},
#     {'text': 'niños', 'type': 'population'},
#     {'text': 'propensos a estar retrasados', 'type': 'outcome'},
#     {'text': '35 %', 'type': 'effect_size'},
#     {'text': '41 %', 'type': 'effect_size'},
#     {'text': 'RP 0.86', 'type': 'effect_size'},
#     {'text': 'niños', 'type': 'population'}],
#    'predicted_entities': [{'text': 'Niños', 'type': 'population'},
#     {'text': 'aldeas CLTS', 'type': 'population'},
#     {'text': 'altura', 'type': 'outcome'},
#     {'text': '0.18 aumento en altura', 'type': 'effect_size'},
#     {'text': 'edad Z puntuación', 'type': 'outcome'},
#     {'text': '95 % IC', 'type': 'coreference'},
#     {'text': '0.03 - 0.32', 'type': 'effect_size'},
#     {'text': '2415 niños', 'type': 'population'},
#     {'text': 'retrasados', 'type': 'outcome'},
#     {'text': '35 %', 'type': 'effect_size'},
#     {'text': '41 %', 'type': 'effect_size'},
#     {'text': 'RP', 'type': 'coreference'},
#     {'text': '0.86', 'type': 'effect_size'},
#     {'text': '95 % IC', 'type': 'coreference'},
#     {'text': '0.74 -1.0', 'type': 'effect_size'},
#     {'text': 'aldeas de control', 'type': 'population'}]},
#   {'sentence': 'No hubo ninguna diferencia significativa entre los grupos en la puntuación media de estrés , ansiedad , depresión , y aumento de peso durante el embarazo a las cuatro semanas después de la intervención y también la frecuencia de parto por cesárea , parto prematuro , y los indicadores antropométricos de los recién nacidos ( p > 0.05 ) .',
#    'expected_entities': [{'text': 'estrés', 'type': 'outcome'},
#     {'text': 'ansiedad', 'type': 'outcome'},
#     {'text': 'depresión', 'type': 'outcome'},
#     {'text': 'aumento de peso', 'type': 'outcome'},
#     {'text': 'la intervención', 'type': 'coreference'},
#     {'text': 'la frecuencia de parto por cesárea', 'type': 'outcome'},
#     {'text': 'parto prematuro', 'type': 'outcome'},
#     {'text': 'los indicadores antropométricos de los recién nacidos',
#      'type': 'outcome'}],
#    'predicted_entities': [{'text': 'puntuación media de estrés',
#      'type': 'outcome'},
#     {'text': 'ansiedad', 'type': 'outcome'},
#     {'text': 'depresión', 'type': 'outcome'},
#     {'text': 'aumento de peso durante el embarazo', 'type': 'outcome'},
#     {'text': 'frecuencia de parto por cesárea', 'type': 'outcome'},
#     {'text': 'parto prematuro', 'type': 'outcome'},
#     {'text': 'indicadores antropométricos de los recién nacidos',
#      'type': 'outcome'},
#     {'text': 'grupos', 'type': 'population'},
#     {'text': 'intervención', 'type': 'intervention'}]},
#   {'sentence': 'Una prueba de conocimiento de presidentes de gobierno de aldea y una encuesta sobre la interacción entre presidentes de aldea y funcionarios de nivel superior revelan que las presidentas de gobierno de aldea tienen mucho menor conocimiento del sistema de gobierno de la aldea que sus homólogos masculinos y tienen significativamente menos contacto con funcionarios de gobierno de nivel superior .',
#    'expected_entities': [{'text': 'prueba', 'type': 'outcome'},
#     {'text': 'presidentes de gobierno de aldea', 'type': 'population'},
#     {'text': 'presidentes de aldea', 'type': 'population'},
#     {'text': 'funcionarios de nivel superior', 'type': 'population'},
#     {'text': 'las presidentas de gobierno de aldea', 'type': 'population'},
#     {'text': 'conocimiento del sistema de gobierno de la aldea',
#      'type': 'outcome'},
#     {'text': 'homólogos', 'type': 'population'},
#     {'text': 'contacto con funcionarios de gobierno de nivel superior',
#      'type': 'outcome'}],
#    'predicted_entities': []},
#   {'sentence': 'Bajo este modelo , 277 jóvenes huérfanos por el SIDA ( de entre 11 y 17 años ) de 15 escuelas comparables fueron asignados aleatoriamente a la atención habitual , que implica la provisión de asesoramiento y suministros relacionados con la educación , o a la condición experimental , en la que los participantes también recibieron cuentas de ahorro igualadas .',
#    'expected_entities': [{'text': 'jóvenes huérfanos por el SIDA ( de entre 11 y 17 años )',
#      'type': 'population'},
#     {'text': 'provisión de asesoramiento y suministros relacionados con la educación',
#      'type': 'intervention'},
#     {'text': 'cuentas de ahorro igualadas', 'type': 'intervention'}],
#    'predicted_entities': [{'text': 'jóvenes huérfanos por el SIDA',
#      'type': 'population'},
#     {'text': '15 escuelas comparables', 'type': 'population'},
#     {'text': 'atención habitual', 'type': 'intervention'},
#     {'text': 'provisión de asesoramiento y suministros relacionados con la educación',
#      'type': 'intervention'},
#     {'text': 'condición experimental', 'type': 'intervention'},
#     {'text': 'participantes', 'type': 'population'},
#     {'text': 'cuentas de ahorro igualadas', 'type': 'intervention'},
#     {'text': 'los participantes', 'type': 'coreference'}]},
#   {'sentence': 'Usando la diferencia - en - diferencias con emparejamiento de puntuación de propensión y las Encuestas de Estándar de Vida de los Hogares de Vietnam de 2004 y 2006 , el artículo encuentra que el aumento del salario mínimo en 2005 redujo la proporción de trabajadores que tienen un empleo en el sector formal entre los trabajadores de bajos salarios .',
#    'expected_entities': [{'text': 'aumento del salario mínimo',
#      'type': 'intervention'},
#     {'text': 'proporción de trabajadores que tienen un empleo en el sector formal',
#      'type': 'outcome'},
#     {'text': 'los trabajadores de bajos salarios', 'type': 'population'}],
#    'predicted_entities': [{'text': 'el aumento del salario mínimo',
#      'type': 'intervention'},
#     {'text': '2005', 'type': 'coreference'},
#     {'text': 'trabajadores de bajos salarios', 'type': 'population'},
#     {'text': 'proporción de trabajadores que tienen un empleo en el sector formal',
#      'type': 'outcome'}]},
#   {'sentence': 'Resultados : El grupo de intervención WASH fue el único grupo en mostrar un aumento significativo en la puntuación Z media de altura-para-edad ( + 0Â · 33 , P = 0Â · 02 ) , con una disminución del 12Â · 1 % en la prevalencia de retraso en el crecimiento , en comparación con el grupo de referencia .',
#    'expected_entities': [{'text': 'intervención WASH', 'type': 'intervention'},
#     {'text': 'puntuación Z media de altura-para-edad', 'type': 'outcome'},
#     {'text': 'prevalencia de retraso en el crecimiento', 'type': 'outcome'}],
#    'predicted_entities': [{'text': 'El grupo de intervención WASH',
#      'type': 'intervention'},
#     {'text': 'puntuación Z media de altura-para-edad', 'type': 'outcome'},
#     {'text': 'prevalencia de retraso en el crecimiento', 'type': 'outcome'},
#     {'text': 'grupo de referencia', 'type': 'population'},
#     {'text': 'WASH', 'type': 'intervention'},
#     {'text': '12Â·1 %', 'type': 'effect_size'}]},
#   {'sentence': 'La incidencia de nacimiento prematuro / BPN en el grupo de intervención ( n = 27 ) fue menor que el grupo de control ( n = 45 ) en un 14.7% ( 95% IC : 2.2 - 27.2 ) ; RR : 0.64 , ( 95% IC : 0.43 - 0.95 ) ; p = 0.023 , X2 = 5.13 .',
#    'expected_entities': [{'text': 'incidencia de nacimiento prematuro / BPN',
#      'type': 'outcome'},
#     {'text': 'el', 'type': 'coreference'},
#     {'text': '14.7%', 'type': 'effect_size'},
#     {'text': 'RR : 0.64', 'type': 'effect_size'}],
#    'predicted_entities': [{'text': 'nacimiento prematuro / BPN',
#      'type': 'outcome'},
#     {'text': 'grupo de intervención', 'type': 'population'},
#     {'text': 'grupo de control', 'type': 'population'},
#     {'text': '14.7%', 'type': 'effect_size'},
#     {'text': '95% IC', 'type': 'coreference'},
#     {'text': '2.2 - 27.2', 'type': 'effect_size'},
#     {'text': 'RR', 'type': 'coreference'},
#     {'text': '0.64', 'type': 'effect_size'},
#     {'text': '95% IC', 'type': 'coreference'},
#     {'text': '0.43 - 0.95', 'type': 'effect_size'},
#     {'text': 'p', 'type': 'coreference'},
#     {'text': '0.023', 'type': 'effect_size'},
#     {'text': 'X2', 'type': 'coreference'},
#     {'text': '5.13', 'type': 'effect_size'}]},
#   ...]}
